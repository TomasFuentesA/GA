# %%
# Imports needed for the script
import numpy as np
import glob
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import tweepy
import json

# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from IPython.display import Image as PImage
from subprocess import check_call
from PIL import Image, ImageDraw, ImageFont
from datetime import date

# %%
test = pd.read_csv (r'dataset.csv', encoding='latin-1')

# %%
test.shape
# Out:
# (52, 10)

# %%
test.head()
# Out:
#       user_id                      user_name      screen_name  follower_count  \
# 0    68504932            DerechoUAntofagasta     DerechoAntof             741
# 1   117199500                   Boris Galvez         bagalvez              69
# 2   574463393  Veronica Duberly Tabilo Muñoz        verotab47            4078
# 3   368773158       Rodrigo Piaggio Marchant  PiaggioMarchant            3569
# 4  1481723006                           ALPU         lori3540            4299
#
#    description  verified  profile_image_default  protected  favourite_count  \
# 0            1         0                      0          0              741
# 1            1         0                      0          0               69
# 2            1         0                      0          0             4078
# 3            1         0                      0          0             3569
# 4            1         0                      0          0             4299
#
#   user_registration
# 0        24-08-2009
# 1        24-02-2010
# 2        08-05-2012
# 3        06-09-2011
# 4        04-06-2013

# %%
test["user_id"]
# Out:
# 0                68504932
# 1               117199500
# 2               574463393
# 3               368773158
# 4              1481723006
# 5     1199881155681640448
# 6     1251979976674619394
# 7               118735179
# 8     1211373950199984128
# 9      769206956871548928
# 10               92259558
# 11    1200422376871215104
# 12               67391751
# 13               64725192
# 14              335681384
# 15              121813315
# 16              740547474
# 17              206045556
# 18    1197247305885323266
# 19    1450455931486183429
# 20             2184876370
# 21     919997511489740801
# 22     832172037070286849
# 23               56266769
# 24              551353047
# 25              387319514
# 26    1388660914828763141
# 27    1380719981944569856
# 28              366923186
# 29              135375527
# 30    1147685269535186944
# 31              168253232
# 32              118817252
# 33    1360188051423715333
# 34             3244813019
# 35     884931206437011457
# 36              122090306
# 37              204930916
# 38              331040088
# 39              613186204
# 40    1454990758948360197
# 41             2471476109
# 42               85651206
# 43              214173942
# 44              255295724
# 45    1186156123088441344
# 46             4502865627
# 47              542992924
# 48    1203650084006703104
# 49             2918033986
# 50               61590292
# 51             2198419465
# Name: user_id, dtype: int64

# %%
test.sort_values(["user_registration"])
# Out:
#                 user_id                         user_name      screen_name  \
# 7             118735179                     Marcelo Tapia    marcelotapiao
# 32            118817252       María José Beltrán Lo prado        Marytha85
# 40  1454990758948360197                       IsAgús ToYs       IsAgustoys
# 47            542992924                     Huichipirichi   sotchiltfemina
# 26  1388660914828763141                        @PabloCano    PabloCanoCura
# 28            366923186                     jose_Montaner    Jose_Montaner
# 4            1481723006                              ALPU         lori3540
# 16            740547474                      Bruno Cortes     twenty_wayne
# 3             368773158          Rodrigo Piaggio Marchant  PiaggioMarchant
# 38            331040088              Venezolanos en Chile  VnezuelaEnChile
# 30  1147685269535186944                      Jota46498094    Jota464980941
# 2             574463393     Veronica Duberly Tabilo Muñoz        verotab47
# 25            387319514               CARMEN HERRERA DÍAZ  __CarmenHerDiaz
# 48  1203650084006703104                Ruthcitachiquitita  Ruthcitachiqui1
# 41           2471476109               Sergio Palma Cabeza     serpalca2014
# 15            121813315                    Manuel SILVA M       Manuel5841
# 27  1380719981944569856         esteban ariel concentrado  arielEsteban199
# 34           3244813019                   zenobia sanchez    chennysanchez
# 43            214173942                 Willmer Escalante          waed682
# 36            122090306                     rodrigo vidal    rodrigovidalp
# 24            551353047              CentroCulturalPalace   PalaceCoquimbo
# 13             64725192                Priscilla Gallardo     prisgallardo
# 33  1360188051423715333                   Camila Basualdo       camibasven
# 35   884931206437011457                             Marce        marce_ccs
# 49           2918033986                           Alfredo        ugedades_
# 23             56266769                              Jess      jnicolethxr
# 14            335681384       juan pablo castillo Geólogo           cuaumo
# 22   832172037070286849                              Jose       ATENAS1976
# 21   919997511489740801                           ArturoH      ArturoH2017
# 51           2198419465                     Juan Marambio    JuanMarambio6
# 46           4502865627              Rancagua más Deporte  DeporteRancagua
# 20           2184876370  Teresa De La Barrera Norambuena.        akelagris
# 31            168253232                      Rodrigo Diaz         diazgola
# 6   1251979976674619394                            Amanda      AAmandapaaz
# 37            204930916                    Danilo Córdova      Mr_Daniloop
# 19  1450455931486183429                    Juan Herquinio         jotaha70
# 39            613186204                      Nico Alegria     Avenger74208
# 12             67391751                       Ari Herrera          alupita
# 18  1197247305885323266                    Connie De Witt   ConnieDeWitt16
# 44            255295724                    Victor Oyarzun      victoraleph
# 29            135375527                MaríaJosé Reyes V.     MariaJoseR_V
# 45  1186156123088441344                              Juan    JMeyerLandrut
# 17            206045556                     Juan Bautista   juaniquillobau
# 1             117199500                      Boris Galvez         bagalvez
# 0              68504932               DerechoUAntofagasta     DerechoAntof
# 10             92259558                            Zeryán          ZeryanG
# 9    769206956871548928              Fernando Arce Daroch      farcedaroch
# 42             85651206                 Jonathan Munizaga      JM_Reviewer
# 5   1199881155681640448                 maria irene arrau       ArrauIrene
# 11  1200422376871215104                  María Echeverria  MaraEcheverria8
# 8   1211373950199984128                          Leonidas  Leonida96579082
# 50             61590292                  Fabián Rodríguez  Don_Tinterillo_
#
#     follower_count  description  verified  profile_image_default  protected  \
# 7              215            1         0                      0          0
# 32             449            1         0                      0          0
# 40               0            1         0                      0          0
# 47              35            0         0                      0          0
# 26             531            1         0                      0          0
# 28            1679            1         0                      0          0
# 4             4299            1         0                      0          0
# 16             142            1         0                      0          0
# 3             3569            1         0                      0          0
# 38           93695            1         0                      0          0
# 30            2863            1         0                      0          0
# 2             4078            1         0                      0          0
# 25             131            1         0                      0          0
# 48              13            1         0                      0          0
# 41             216            0         0                      0          0
# 15              27            0         0                      0          0
# 27             333            1         0                      0          0
# 34             214            0         0                      0          0
# 43            1115            1         0                      0          0
# 36             751            1         0                      0          0
# 24            3798            1         0                      0          0
# 13            1140            1         0                      0          0
# 33             590            1         0                      0          0
# 35             662            0         0                      0          0
# 49             915            1         0                      0          0
# 23             539            1         0                      0          0
# 14             228            1         0                      0          0
# 22               1            0         0                      0          0
# 21            1719            1         0                      0          0
# 51            1891            1         0                      0          0
# 46            5106            1         0                      0          0
# 20            9964            1         0                      0          0
# 31             309            0         0                      0          0
# 6               78            1         0                      0          0
# 37             835            1         0                      0          0
# 19               0            0         0                      0          0
# 39            7861            1         0                      0          0
# 12             209            1         0                      0          0
# 18            2624            1         0                      0          0
# 44             741            1         0                      0          0
# 29             925            1         0                      0          0
# 45             168            1         0                      0          0
# 17            2391            1         0                      0          0
# 1               69            1         0                      0          0
# 0              741            1         0                      0          0
# 10            1089            1         0                      0          0
# 9             3156            1         0                      0          0
# 42            4702            1         0                      0          0
# 5               39            0         0                      0          0
# 11               2            1         0                      0          0
# 8             1954            1         0                      0          0
# 50            5004            1         0                      0          0
#
#     favourite_count user_registration
# 7               215        01-03-2010
# 32              449        01-03-2010
# 40                0        01-11-2021
# 47               35        02-04-2012
# 26              531        02-05-2021
# 28             1679        03-09-2011
# 4              4299        04-06-2013
# 16              142        06-08-2012
# 3              3569        06-09-2011
# 38            93695        07-07-2011
# 30             2863        07-07-2019
# 2              4078        08-05-2012
# 25              131        08-10-2011
# 48               13        08-12-2019
# 41              216        09-04-2014
# 15               27        10-03-2010
# 27              333        10-04-2021
# 34              214        10-05-2015
# 43             1115        10-11-2010
# 36              751        11-03-2010
# 24             3798        11-04-2012
# 13             1140        11-08-2009
# 33              590        12-02-2021
# 35              662        12-07-2017
# 49              915        12-12-2014
# 23              539        13-07-2009
# 14              228        15-07-2011
# 22                1        16-02-2017
# 21             1719        16-10-2017
# 51             1891        16-11-2013
# 46             5106        16-12-2015
# 20             9964        17-11-2013
# 31              309        18-07-2010
# 6                78        19-04-2020
# 37              835        19-10-2010
# 19                0        19-10-2021
# 39             7861        20-06-2012
# 12              209        20-08-2009
# 18             2624        20-11-2019
# 44              741        21-02-2011
# 29              925        21-04-2010
# 45              168        21-10-2019
# 17             2391        22-10-2010
# 1                69        24-02-2010
# 0               741        24-08-2009
# 10             1089        24-11-2009
# 9              3156        26-08-2016
# 42             4702        27-10-2009
# 5                39        28-11-2019
# 11                2        29-11-2019
# 8              1954        29-12-2019
# 50             5004        30-07-2009

# %%
ocurrencies = {}
users = []
for index, row in test.iterrows():
    if (row['user_registration'][2:12] in ocurrencies and row['user_id'] not in users) :
        users.append(row['user_id'])
        ocurrencies[row['user_registration'][2:12]] += 1
    elif (row['user_registration'][2:12] in ocurrencies and row['user_id'] in users):
        continue
    else:
        users.append(row['user_id'])
        ocurrencies[row['user_registration'][2:12]] = 1
 
print(users)
plt.bar(ocurrencies.keys(), ocurrencies.values())
# Out:
# [68504932, 117199500, 574463393, 368773158, 1481723006, 1199881155681640448, 1251979976674619394, 118735179, 1211373950199984128, 769206956871548928, 92259558, 1200422376871215104, 67391751, 64725192, 335681384, 121813315, 740547474, 206045556, 1197247305885323266, 1450455931486183429, 2184876370, 919997511489740801, 832172037070286849, 56266769, 551353047, 387319514, 1388660914828763141, 1380719981944569856, 366923186, 135375527, 1147685269535186944, 168253232, 118817252, 1360188051423715333, 3244813019, 884931206437011457, 122090306, 204930916, 331040088, 613186204, 1454990758948360197, 2471476109, 85651206, 214173942, 255295724, 1186156123088441344, 4502865627, 542992924, 1203650084006703104, 2918033986, 61590292, 2198419465]
# <BarContainer object of 38 artists>

# %%
#Credenciales

API_KEY = 'xYLe5IZ7LdnWEgef8v1k0jqEt'
API_KEY_SECRET = 'z3cW3xLWIYP6OoLAxsOx4cpex5IjCr8InLWLt9WxlBbpvtTJq2'
ACCESS_TOKEN = '376338170-R3SPxz9gK1eks3TfekwnRcKmMfAfEnMDg3MN42n5'
ACCESS_TOKEN_SECRET = '0jGCULO47TTF6glVUO2Vxcax2kEqi5byk9ajeFg89EBct'

#Autenticación
auth = tweepy.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth, wait_on_rate_limit = True)



#print(json.dumps(user._json,indent=2))

#print(user._json['protected'])

# %%
most_used = ['screen_name', 'follower_count', 'description', 'verified', 'profile_image', 'protected', 'favourite_count','user_registration']
dropped = ['screen_name', 'user_registration']


test['mappedVerified'] = test['verified']
test['mappedProtected'] = test['protected']
test['mappedDefaultImage'] = test['profile_image_default']
test['mappedDescription'] = test['description']
mappedUserName = []
mappedAge = []
error_id = []
for index, row in test.iterrows():
    
    try:
        name = ""
        for i in range (len(row['user_name'].lower().split())):
            name+=row['user_name'].lower().split()[i]
        
        if name in row['screen_name'].lower():
            mappedUserName.append(1)
        else:
            mappedUserName.append(0)
            
        age = abs(2021 - int(row['user_registration'][6:10]))
        mappedAge.append(age)

    except:
        print(row['user_id'])
        error_id.append(row['user_id'])
        continue

test['mappedUserName'] = mappedUserName
test['mappedAge'] = mappedAge

users_encoded = test.drop(dropped, axis = 1)
# Out:
# 12
# 11
# 9
# 10
# 8
# 2
# 1
# 11
# 2
# 5
# 12
# 2
# 12
# 12
# 10
# 11
# 9
# 11
# 2
# 0
# 8
# 4
# 4
# 12
# 9
# 10
# 0
# 0
# 10
# 11
# 2
# 11
# 11
# 0
# 6
# 4
# 11
# 11
# 10
# 9
# 0
# 7
# 12
# 11
# 10
# 2
# 6
# 9
# 2
# 7
# 12
# 8
# '\n\nusers_encoded = test.drop(dropped, axis = 1)\nusers_encoded\n'

# %%
users_encoded
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_313/2923139672.py in <module>
# ----> 1 users_encoded
#
# NameError: name 'users_encoded' is not defined
