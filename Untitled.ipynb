# %%
# Imports

import glob
import string
import ast
import math

# pandas
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
from scipy import interp
from itertools import cycle
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.tree import DecisionTreeClassifier, export_graphviz 
from sklearn.ensemble import ExtraTreesClassifier, VotingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier


#metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer, accuracy_score, confusion_matrix, f1_score
from sklearn.metrics import precision_recall_fscore_support, classification_report
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# <h1>Importación CSV</h1>

# %%
train = pd.DataFrame()
for f in glob.glob('Train.csv'):
    df = pd.read_csv(f, encoding='ISO-8859–1')
    train = train.append(df,ignore_index=True)

# %%
test = pd.DataFrame()
for f in glob.glob('Test.csv'):
    df = pd.read_csv(f, encoding='ISO-8859–1')
    test = test.append(df,ignore_index=True)

# %%
validSet = pd.DataFrame()
for f in glob.glob('Validation.csv'):
    df = pd.read_csv(f, encoding='ISO-8859–1')
    validSet = validSet.append(df,ignore_index=True)

# %%
train.shape, validSet.shape, test.shape
# Out:
# ((2230, 37), (558, 37), (575, 37))

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2230 non-null   object
#  1   followers_count        2215 non-null   float64
#  2   friends_count          2215 non-null   float64
#  3   listedcount            2215 non-null   float64
#  4   favourites_count       2215 non-null   float64
#  5   verified               2215 non-null   float64
#  6   statuses_count         2215 non-null   float64
#  7   default_profile        2215 non-null   float64
#  8   default_profile_image  2215 non-null   float64
#  9   has_extended_profile   2215 non-null   float64
#  10  name                   2215 non-null   object
#  11  bot                    2215 non-null   float64
#  12  In_reply               2215 non-null   float64
#  13  retweet_count          2215 non-null   float64
#  14  fav_count              2215 non-null   float64
#  15  total_usrmention       2215 non-null   float64
#  16  days_std               2215 non-null   float64
#  17  hours_std              2215 non-null   float64
#  18  modified_hour          2215 non-null   float64
#  19  acc_age                2215 non-null   float64
#  20  tweets_per_day         2215 non-null   float64
#  21  in_reply_data          2215 non-null   float64
#  22  ff_ratio               2215 non-null   float64
#  23  sn_length              2215 non-null   float64
#  24  desc_length            2215 non-null   float64
#  25  diversity              2215 non-null   float64
#  26  name_length            2215 non-null   float64
#  27  name_words             2215 non-null   float64
#  28  null_url               2215 non-null   float64
#  29  screennamebot          2215 non-null   float64
#  30  namebot                2215 non-null   float64
#  31  descbot                2215 non-null   float64
#  32  nameratio              2215 non-null   float64
#  33  avg_In_reply           2215 non-null   float64
#  34  avg_retweet_count      2215 non-null   float64
#  35  avg_fav_count          2215 non-null   float64
#  36  avg_total_usrmention   2215 non-null   float64
# dtypes: float64(35), object(2)
# memory usage: 644.7+ KB

# %%
xset = train
X_all = xset.drop(['id','bot','name'], axis=1)
y_all = xset['bot']
'''
X_all = X_all.fillna(0)
print(X_all)
y_all = y_all.fillna(0)
print(y_all)
'''
# Out:
# '\nX_all = X_all.fillna(0)\nprint(X_all)\ny_all = y_all.fillna(0)\nprint(y_all)\n'

# %%
# Create the RFE object and compute a cross-validated score.
model = ExtraTreesClassifier()
rfecv = RFECV(estimator=model, step=1, cv=StratifiedKFold(10),scoring='accuracy')

X_all = X_all.replace(np.nan,0)
y_all = y_all.replace(np.nan,0)


       
rfecv.fit(X_all, y_all)

print("Optimal number of features : %d" % rfecv.n_features_)

# Plot number of features VS. cross-validation scores
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()
# Out:
# /mnt/d/GA/GA/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but RFECV was fitted with feature names
#   warnings.warn(
# /mnt/d/GA/GA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: The `grid_scores_` attribute is deprecated in version 1.0 in favor of `cv_results_` and will be removed in version 1.2.
#   warnings.warn(msg, category=FutureWarning)
# Optimal number of features : 34

# %%
from sklearn.ensemble import ExtraTreesClassifier
model2 = ExtraTreesClassifier()
model2.fit(X_all, y_all)

#Add features and their importances to a dictionary
feature_imp_dict = dict(zip(X_all.columns.values, model2.feature_importances_))

for x in sorted(zip(model2.feature_importances_,list(X_all)))[::-1]:
    print(x)
# Out:
# (0.12199444672193521, 'acc_age')
# (0.09973402697131663, 'verified')
# (0.06356916932487865, 'descbot')
# (0.053838503822528416, 'default_profile')
# (0.053101456098370255, 'avg_In_reply')
# (0.0506196407444207, 'In_reply')
# (0.042579856757819244, 'avg_total_usrmention')
# (0.036134796544991146, 'avg_fav_count')
# (0.03569354770879746, 'total_usrmention')
# (0.03106268110901446, 'fav_count')
# (0.029951178663085123, 'avg_retweet_count')
# (0.029937783104805347, 'hours_std')
# (0.026368417314337103, 'retweet_count')
# (0.023384492981328105, 'days_std')
# (0.02222956202044926, 'screennamebot')
# (0.02216961744944228, 'tweets_per_day')
# (0.020052708330890772, 'has_extended_profile')
# (0.017603411938689303, 'friends_count')
# (0.01751163557727452, 'desc_length')
# (0.01662021199263406, 'statuses_count')
# (0.01621429343868446, 'sn_length')
# (0.01596223802316672, 'namebot')
# (0.015283588148431148, 'favourites_count')
# (0.015109252653207767, 'nameratio')
# (0.014695375921992477, 'ff_ratio')
# (0.014661321386139821, 'name_words')
# (0.014471199860252328, 'name_length')
# (0.01383305864969096, 'listedcount')
# (0.013712534679846138, 'followers_count')
# (0.01347075678347069, 'null_url')
# (0.012372256897956372, 'modified_hour')
# (0.01194280294793331, 'diversity')
# (0.0075189606979064825, 'in_reply_data')
# (0.006595214734313258, 'default_profile_image')

# %%
#define a function to print ROC curves. 
#It should take in only arrays/lists of predictions and outcomes
from sklearn.metrics import roc_curve, auc

def plotUnivariateROC(preds, truth, label_string):
    '''
    preds is an nx1 array of predictions
    truth is an nx1 array of truth labels
    label_string is text to go into the plotting label
    '''
    #Student input code here
    #1. call the roc_curve function to get the ROC X and Y values
    fpr, tpr, thresholds = roc_curve(truth, preds)
    #2. Input fpr and tpr into the auc function to get the AUC
    roc_auc = auc(fpr, tpr)
    
    #we are doing this as a special case because we are sending unfitted predictions
    #into the function
    if roc_auc < 0.5:
        fpr, tpr, thresholds = roc_curve(truth, -1 * preds)
        roc_auc = auc(fpr, tpr)

    #chooses a random color for plotting
    c = (np.random.rand(), np.random.rand(), np.random.rand())

    #create a plot and set some options
    plt.plot(fpr, tpr, color = c, label = label_string + ' (AUC = %0.3f)' % roc_auc)
    

    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.title('ROC')
    plt.legend(loc="lower right")
    
    return roc_auc

# %%
fig = plt.figure(figsize = (12, 6))
ax = plt.subplot(111)

#Plot the univariate AUC on the training data. Store the AUC

#Student put code here
feature_auc_dict = {}
for col in X_all.columns:
    feature_auc_dict[col] = plotUnivariateROC(X_all[col], y_all, col)


# Put a legend below current axis
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.0 , box.width, box.height * 1])
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.15), fancybox = True, 
              shadow = True, ncol = 4, prop = {'size':10})

# %%
#Add auc and mi each to a single dataframe
df_auc = pd.DataFrame(pd.Series(feature_auc_dict), columns = ['auc'])
df_imp = pd.DataFrame(pd.Series(feature_imp_dict), columns = ['imp'])

#Now merge the two on the feature name
feat_imp_df = df_auc.merge(df_imp, left_index = True, right_index = True)
feat_imp_df
# Out:
#                             auc       imp
# followers_count        0.756198  0.013713
# friends_count          0.756211  0.017603
# listedcount            0.670331  0.013833
# favourites_count       0.786784  0.015284
# verified               0.709599  0.099734
# statuses_count         0.538902  0.016620
# default_profile        0.699430  0.053839
# default_profile_image  0.525614  0.006595
# has_extended_profile   0.577808  0.020053
# In_reply               0.802171  0.050620
# retweet_count          0.703615  0.026368
# fav_count              0.732273  0.031063
# total_usrmention       0.742403  0.035694
# days_std               0.630000  0.023384
# hours_std              0.652485  0.029938
# modified_hour          0.502055  0.012372
# acc_age                0.852428  0.121994
# tweets_per_day         0.640444  0.022170
# in_reply_data          0.534284  0.007519
# ff_ratio               0.570610  0.014695
# sn_length              0.600234  0.016214
# desc_length            0.537488  0.017512
# diversity              0.516976  0.011943
# name_length            0.576480  0.014471
# name_words             0.504193  0.014661
# null_url               0.612201  0.013471
# screennamebot          0.578309  0.022230
# namebot                0.569114  0.015962
# descbot                0.638890  0.063569
# nameratio              0.578153  0.015109
# avg_In_reply           0.802171  0.053101
# avg_retweet_count      0.703615  0.029951
# avg_fav_count          0.732273  0.036135
# avg_total_usrmention   0.742403  0.042580

# %%
#Now create a df that holds the ranks of auc and mi 
feat_ranks = feat_imp_df.rank(axis = 0, ascending = False)

#Plot the two ranks
plt.plot(feat_ranks.auc, feat_ranks.imp, '.')
#Plot a y=x reference line
plt.plot(feat_ranks.auc, feat_ranks.auc,)

# %%
#Now create lists of top 10 features for both auc and mi
top5_auc = list(feat_ranks[(feat_ranks.auc <= 26)].index.values)
top5_imp = list(feat_ranks[(feat_ranks.imp <= 26)].index.values)
for x in zip(top5_auc, top5_imp):
    print(x)
# Out:
# ('followers_count', 'friends_count')
# ('friends_count', 'favourites_count')
# ('listedcount', 'verified')
# ('favourites_count', 'statuses_count')
# ('verified', 'default_profile')
# ('default_profile', 'has_extended_profile')
# ('has_extended_profile', 'In_reply')
# ('In_reply', 'retweet_count')
# ('retweet_count', 'fav_count')
# ('fav_count', 'total_usrmention')
# ('total_usrmention', 'days_std')
# ('days_std', 'hours_std')
# ('hours_std', 'acc_age')
# ('acc_age', 'tweets_per_day')
# ('tweets_per_day', 'ff_ratio')
# ('ff_ratio', 'sn_length')
# ('sn_length', 'desc_length')
# ('name_length', 'name_words')
# ('null_url', 'screennamebot')
# ('screennamebot', 'namebot')
# ('descbot', 'descbot')
# ('nameratio', 'nameratio')
# ('avg_In_reply', 'avg_In_reply')
# ('avg_retweet_count', 'avg_retweet_count')
# ('avg_fav_count', 'avg_fav_count')
# ('avg_total_usrmention', 'avg_total_usrmention')

# %%
'''
Now do the following
1. Split the data into 80/20 train/test
2. For each set of features:
- build two decision trees (max_depth in {10, 20}) 
- build two logistic regression (C in {10**-2, 10**2})
- get the auc and log-loss on the test set
'''


def getLogLoss(Ps, Ys, eps = 10**-6):
    return ((Ys == 1) * np.log(Ps + eps) + (Ys == 0) * np.log(1 - Ps + eps)).mean()

#Split into train and test randomly without using sklearn package
#Note, there are many ways to do this:

train_pct = 0.8
#1. create an array of n random uniform variables drawn on [0,1] range
rand = np.random.rand(X_all.shape[0])
#2. Convert to boolean where True = random number < train_pct
rand_filt = (rand < train_pct)

#Use the filter to index data

train = X_all[rand_filt]
test = X_all[(rand_filt == False)]


fsets = [top5_auc, top5_imp]
fset_descr = ['auc', 'imp']
mxdepths = [5]
Cs = [10**2]


#Set up plotting box
fig = plt.figure(figsize = (15, 8))
ax = plt.subplot(111)


for i, fset in enumerate(fsets):
    descr = fset_descr[i]
    #set training and testing data
    Y_train = y_all
    X_train = X_all[fset]
    Y_test = y_all
    X_test = X_all[fset]
    
    for d in mxdepths:
        dt = DecisionTreeClassifier(criterion = 'entropy', max_depth = d)
        dt.fit(X_train, Y_train)
        preds_dt = dt.predict_proba(X_test)[:, 1]
        ll_dt = getLogLoss(preds_dt, Y_test)
        
        plotUnivariateROC(preds_dt, Y_test, '{}:DT:md={}:(LL={})'.format(descr, d, round(ll_dt, 3)))

        
    for C in Cs:
        lr = LogisticRegression(C = C)
        lr.fit(X_train, Y_train)
        preds_lr = lr.predict_proba(X_test)[:, 1]
        ll_lr = getLogLoss(preds_lr, Y_test)

        plotUnivariateROC(preds_lr, Y_test, '{}:LR:C={}:(LL={})'.format(descr, C, round(ll_lr, 3)))

    
# Put a legend below current axis
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.0 , box.width, box.height * 1])
ax.legend(loc = 'upper center', bbox_to_anchor = (0.5, -0.15), fancybox = True, 
              shadow = True, ncol = 2, prop = {'size':10})
# Out:
# /mnt/d/GA/GA/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /mnt/d/GA/GA/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
features = list(top5_imp)
X_train = train[features]
y_train = xset['bot']
X_test = validSet[features]
y_test = validSet['bot']
final_test = test[features]

# %%
features2 = ['acc_age','default_profile','descbot','fav_count','favourites_count','ff_ratio','followers_count',\
                   'friends_count','has_extended_profile','listedcount','name_length','nameratio','null_url',\
                   'screennamebot','sn_length','tweets_per_day','verified']
X_train2 = train[features2]
y_train2 = xset['bot']
X_test2 = validSet[features2]
y_test2 = validSet['bot']
final_test2 = test[features2]

# %%
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
poly_feature = PolynomialFeatures(degree=3)

X_train =  poly_feature.fit_transform(X_train)
X_test =  poly_feature.fit_transform(X_test)
final_test = poly_feature.transform(final_test)

X_train2 =  poly_feature.fit_transform(X_train2)
X_test2 =  poly_feature.fit_transform(X_test2)
final_test2 = poly_feature.transform(final_test2)

fs_m1 = StandardScaler().fit(X_train) 
fs_m2 = StandardScaler().fit(X_train2)

Xs_train = fs_m1.transform(X_train)
Xs_train2 = fs_m2.fit_transform(X_train2)


Xs_test = fs_m1.transform(X_test)
Xs_test2 = fs_m2.transform(X_test2)

sfinal_test1 = fs_m1.transform(final_test)
sfinal_test2 = fs_m2.transform(final_test2)

# %% [markdown]
# <h1>Modelos</h1>
# <h4>Árbol de Decisión</h4>

# %%
# Decision Tree

clf = DecisionTreeClassifier()

parameters = {'max_features': [10,12,14,16], 
              'criterion': ['entropy', 'gini'],
              'max_depth': [3, 5, 6, 8, 10], 
              'min_samples_split': [10, 20, 30],
              'min_samples_leaf': [1,5,8],
              'min_impurity_split': [0.00000001, 0.0000001]
             }

acc_scorer = make_scorer(accuracy_score)

#grid search
grid_obj = GridSearchCV(clf, parameters, scoring=acc_scorer)
grid_obj = grid_obj.fit(Xs_train2, y_train)

# Set the clf to the best combination of parameters
clf = grid_obj.best_estimator_

clf.fit(Xs_train2, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1679/2549716137.py in <module>
#      15 #grid search
#      16 grid_obj = GridSearchCV(clf, parameters, scoring=acc_scorer)
# ---> 17 grid_obj = grid_obj.fit(Xs_train2, y_train)
#      18
#      19 # Set the clf to the best combination of parameters
#
# /mnt/d/GA/GA/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     797             refit_metric = self.refit
#     798
# --> 799         X, y, groups = indexable(X, y, groups)
#     800         fit_params = _check_fit_params(X, fit_params)
#     801
#
# /mnt/d/GA/GA/lib/python3.8/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     368     """
#     369     result = [_make_indexable(X) for X in iterables]
# --> 370     check_consistent_length(*result)
#     371     return result
#     372
#
# /mnt/d/GA/GA/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     329     uniques = np.unique(lengths)
#     330     if len(uniques) > 1:
# --> 331         raise ValueError(
#     332             "Found input variables with inconsistent numbers of samples: %r"
#     333             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [1809, 2230]
